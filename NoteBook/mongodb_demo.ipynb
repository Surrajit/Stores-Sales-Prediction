# %%
import pandas as pd

# %%
df = pd.read_csv("Data/Train.csv")
df.head(4)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
data = df.to_dict(orient="records")
data
# Out:
# [{'Item_Identifier': 'FDA15',
#   'Item_Weight': 9.3,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.016047301,
#   'Item_Type': 'Dairy',
#   'Item_MRP': 249.8092,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 3735.138},
#  {'Item_Identifier': 'DRC01',
#   'Item_Weight': 5.92,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.019278216,
#   'Item_Type': 'Soft Drinks',
#   'Item_MRP': 48.2692,
#   'Outlet_Identifier': 'OUT018',
#   'Outlet_Establishment_Year': 2009,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type2',
#   'Item_Outlet_Sales': 443.4228},
#  {'Item_Identifier': 'FDN15',
#   'Item_Weight': 17.5,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.016760075,
#   'Item_Type': 'Meat',
#   'Item_MRP': 141.618,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2097.27},
#  {'Item_Identifier': 'FDX07',
#   'Item_Weight': 19.2,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.0,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 182.095,
#   'Outlet_Identifier': 'OUT010',
#   'Outlet_Establishment_Year': 1998,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 732.38},
#  {'Item_Identifier': 'NCD19',
#   'Item_Weight': 8.93,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.0,
#   'Item_Type': 'Household',
#   'Item_MRP': 53.8614,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 994.7052},
#  {'Item_Identifier': 'FDP36',
#   'Item_Weight': 10.395,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.0,
#   'Item_Type': 'Baking Goods',
#   'Item_MRP': 51.4008,
#   'Outlet_Identifier': 'OUT018',
#   'Outlet_Establishment_Year': 2009,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type2',
#   'Item_Outlet_Sales': 556.6088},
#  {'Item_Identifier': 'FDO10',
#   'Item_Weight': 13.65,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.012741089,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 57.6588,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 343.5528},
#  {'Item_Identifier': 'FDP10',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.127469857,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 107.7622,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 4022.7636},
#  {'Item_Identifier': 'FDH17',
#   'Item_Weight': 16.2,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.016687114,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 96.9726,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1076.5986},
#  {'Item_Identifier': 'FDU28',
#   'Item_Weight': 19.2,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.09444959,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 187.8214,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 4710.535},
#  {'Item_Identifier': 'FDY07',
#   'Item_Weight': 11.8,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.0,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 45.5402,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1516.0266},
#  {'Item_Identifier': 'FDA03',
#   'Item_Weight': 18.5,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.045463773,
#   'Item_Type': 'Dairy',
#   'Item_MRP': 144.1102,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2187.153},
#  {'Item_Identifier': 'FDX32',
#   'Item_Weight': 15.1,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.1000135,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 145.4786,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1589.2646},
#  {'Item_Identifier': 'FDS46',
#   'Item_Weight': 17.6,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.047257328,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 119.6782,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2145.2076},
#  {'Item_Identifier': 'FDF32',
#   'Item_Weight': 16.35,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.0680243,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 196.4426,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1977.426},
#  {'Item_Identifier': 'FDP49',
#   'Item_Weight': 9.0,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.069088961,
#   'Item_Type': 'Breakfast',
#   'Item_MRP': 56.3614,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1547.3192},
#  {'Item_Identifier': 'NCB42',
#   'Item_Weight': 11.8,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.008596051,
#   'Item_Type': 'Health and Hygiene',
#   'Item_MRP': 115.3492,
#   'Outlet_Identifier': 'OUT018',
#   'Outlet_Establishment_Year': 2009,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type2',
#   'Item_Outlet_Sales': 1621.8888},
#  {'Item_Identifier': 'FDP49',
#   'Item_Weight': 9.0,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.069196376,
#   'Item_Type': 'Breakfast',
#   'Item_MRP': 54.3614,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 718.3982},
#  {'Item_Identifier': 'DRI11',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.034237682,
#   'Item_Type': 'Hard Drinks',
#   'Item_MRP': 113.2834,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 2303.668},
#  {'Item_Identifier': 'FDU02',
#   'Item_Weight': 13.35,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.10249212,
#   'Item_Type': 'Dairy',
#   'Item_MRP': 230.5352,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2748.4224},
#  {'Item_Identifier': 'FDN22',
#   'Item_Weight': 18.85,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.138190277,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 250.8724,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 3775.086},
#  {'Item_Identifier': 'FDW12',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.035399923,
#   'Item_Type': 'Baking Goods',
#   'Item_MRP': 144.5444,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 4064.0432},
#  {'Item_Identifier': 'NCB30',
#   'Item_Weight': 14.6,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.025698134,
#   'Item_Type': 'Household',
#   'Item_MRP': 196.5084,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1587.2672},
#  {'Item_Identifier': 'FDC37',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.057556998,
#   'Item_Type': 'Baking Goods',
#   'Item_MRP': 107.6938,
#   'Outlet_Identifier': 'OUT019',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 214.3876},
#  {'Item_Identifier': 'FDR28',
#   'Item_Weight': 13.85,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.025896485,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 165.021,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 4078.025},
#  {'Item_Identifier': 'NCD06',
#   'Item_Weight': 13.0,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.099887103,
#   'Item_Type': 'Household',
#   'Item_MRP': 45.906,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 838.908},
#  {'Item_Identifier': 'FDV10',
#   'Item_Weight': 7.645,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.066693437,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 42.3112,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1065.28},
#  {'Item_Identifier': 'DRJ59',
#   'Item_Weight': 11.65,
#   'Item_Fat_Content': 'low fat',
#   'Item_Visibility': 0.019356132,
#   'Item_Type': 'Hard Drinks',
#   'Item_MRP': 39.1164,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 308.9312},
#  {'Item_Identifier': 'FDE51',
#   'Item_Weight': 5.925,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.161466534,
#   'Item_Type': 'Dairy',
#   'Item_MRP': 45.5086,
#   'Outlet_Identifier': 'OUT010',
#   'Outlet_Establishment_Year': 1998,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 178.4344},
#  {'Item_Identifier': 'FDC14',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.072221801,
#   'Item_Type': 'Canned',
#   'Item_MRP': 43.6454,
#   'Outlet_Identifier': 'OUT019',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 125.8362},
#  {'Item_Identifier': 'FDV38',
#   'Item_Weight': 19.25,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.170348551,
#   'Item_Type': 'Dairy',
#   'Item_MRP': 55.7956,
#   'Outlet_Identifier': 'OUT010',
#   'Outlet_Establishment_Year': 1998,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 163.7868},
#  {'Item_Identifier': 'NCS17',
#   'Item_Weight': 18.6,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.080829372,
#   'Item_Type': 'Health and Hygiene',
#   'Item_MRP': 96.4436,
#   'Outlet_Identifier': 'OUT018',
#   'Outlet_Establishment_Year': 2009,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type2',
#   'Item_Outlet_Sales': 2741.7644},
#  {'Item_Identifier': 'FDP33',
#   'Item_Weight': 18.7,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.0,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 256.6672,
#   'Outlet_Identifier': 'OUT018',
#   'Outlet_Establishment_Year': 2009,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type2',
#   'Item_Outlet_Sales': 3068.0064},
#  {'Item_Identifier': 'FDO23',
#   'Item_Weight': 17.85,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.0,
#   'Item_Type': 'Breads',
#   'Item_MRP': 93.1436,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2174.5028},
#  {'Item_Identifier': 'DRH01',
#   'Item_Weight': 17.5,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.097904029,
#   'Item_Type': 'Soft Drinks',
#   'Item_MRP': 174.8738,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2085.2856},
#  {'Item_Identifier': 'NCX29',
#   'Item_Weight': 10.0,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.089291137,
#   'Item_Type': 'Health and Hygiene',
#   'Item_MRP': 146.7102,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 3791.0652},
#  {'Item_Identifier': 'FDV20',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.059511812,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 128.0678,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 2797.6916},
#  {'Item_Identifier': 'DRZ11',
#   'Item_Weight': 8.85,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.113123893,
#   'Item_Type': 'Soft Drinks',
#   'Item_MRP': 122.5388,
#   'Outlet_Identifier': 'OUT018',
#   'Outlet_Establishment_Year': 2009,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type2',
#   'Item_Outlet_Sales': 1609.9044},
#  {'Item_Identifier': 'FDX10',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.123111453,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 36.9874,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 388.1614},
#  {'Item_Identifier': 'FDB34',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.026480954,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 87.6198,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 2180.495},
#  {'Item_Identifier': 'FDU02',
#   'Item_Weight': 13.35,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.102511504,
#   'Item_Type': 'Dairy',
#   'Item_MRP': 230.6352,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 3435.528},
#  {'Item_Identifier': 'FDK43',
#   'Item_Weight': 9.8,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.02681843,
#   'Item_Type': 'Meat',
#   'Item_MRP': 126.002,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2150.534},
#  {'Item_Identifier': 'FDA46',
#   'Item_Weight': 13.6,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.117818348,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 192.9136,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2527.3768},
#  {'Item_Identifier': 'FDC02',
#   'Item_Weight': 21.35,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.069102831,
#   'Item_Type': 'Canned',
#   'Item_MRP': 259.9278,
#   'Outlet_Identifier': 'OUT018',
#   'Outlet_Establishment_Year': 2009,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type2',
#   'Item_Outlet_Sales': 6768.5228},
#  {'Item_Identifier': 'FDL50',
#   'Item_Weight': 12.15,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.042277867,
#   'Item_Type': 'Canned',
#   'Item_MRP': 126.5046,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 373.5138},
#  {'Item_Identifier': 'FDM39',
#   'Item_Weight': 6.42,
#   'Item_Fat_Content': 'LF',
#   'Item_Visibility': 0.089498926,
#   'Item_Type': 'Dairy',
#   'Item_MRP': 178.1002,
#   'Outlet_Identifier': 'OUT010',
#   'Outlet_Establishment_Year': 1998,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 358.2004},
#  {'Item_Identifier': 'NCP05',
#   'Item_Weight': 19.6,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.0,
#   'Item_Type': 'Health and Hygiene',
#   'Item_MRP': 153.3024,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2428.8384},
#  {'Item_Identifier': 'FDV49',
#   'Item_Weight': 10.0,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.025879577,
#   'Item_Type': 'Canned',
#   'Item_MRP': 265.2226,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 5815.0972},
#  {'Item_Identifier': 'FDL12',
#   'Item_Weight': 15.85,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.121632721,
#   'Item_Type': 'Baking Goods',
#   'Item_MRP': 60.622,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2576.646},
#  {'Item_Identifier': 'FDS02',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.255394896,
#   'Item_Type': 'Dairy',
#   'Item_MRP': 196.8794,
#   'Outlet_Identifier': 'OUT019',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 780.3176},
#  {'Item_Identifier': 'NCL17',
#   'Item_Weight': 7.39,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.067779712,
#   'Item_Type': 'Health and Hygiene',
#   'Item_MRP': 143.8812,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 3134.5864},
#  {'Item_Identifier': 'FDM40',
#   'Item_Weight': 10.195,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.159803853,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 141.5154,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 850.8924},
#  {'Item_Identifier': 'FDR13',
#   'Item_Weight': 9.895,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.028696932,
#   'Item_Type': 'Canned',
#   'Item_MRP': 117.0492,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 810.9444},
#  {'Item_Identifier': 'FDA43',
#   'Item_Weight': 10.895,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.065041581,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 196.3794,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 3121.2704},
#  {'Item_Identifier': 'NCP18',
#   'Item_Weight': 12.15,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.028760013,
#   'Item_Type': 'Household',
#   'Item_MRP': 151.4708,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 4815.0656},
#  {'Item_Identifier': 'FDK21',
#   'Item_Weight': 7.905,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.010053105,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 249.0408,
#   'Outlet_Identifier': 'OUT018',
#   'Outlet_Establishment_Year': 2009,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type2',
#   'Item_Outlet_Sales': 6258.52},
#  {'Item_Identifier': 'NCX54',
#   'Item_Weight': 9.195,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.048157338,
#   'Item_Type': 'Household',
#   'Item_MRP': 106.1622,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2117.244},
#  {'Item_Identifier': 'DRK35',
#   'Item_Weight': 8.365,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.071958197,
#   'Item_Type': 'Hard Drinks',
#   'Item_MRP': 38.0506,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 796.9626},
#  {'Item_Identifier': 'FDY21',
#   'Item_Weight': 15.1,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.173481304,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 194.511,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 4910.275},
#  {'Item_Identifier': 'FDI26',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.061082177,
#   'Item_Type': 'Canned',
#   'Item_MRP': 180.0344,
#   'Outlet_Identifier': 'OUT019',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 892.172},
#  {'Item_Identifier': 'FDM20',
#   'Item_Weight': 10.0,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.0,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 246.9144,
#   'Outlet_Identifier': 'OUT018',
#   'Outlet_Establishment_Year': 2009,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type2',
#   'Item_Outlet_Sales': 3185.1872},
#  {'Item_Identifier': 'FDV27',
#   'Item_Weight': 7.97,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.040071131,
#   'Item_Type': 'Meat',
#   'Item_MRP': 87.3514,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1062.6168},
#  {'Item_Identifier': 'FDF09',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.012090074,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 38.2848,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 484.7024},
#  {'Item_Identifier': 'FDY40',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.15028599,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 51.0692,
#   'Outlet_Identifier': 'OUT019',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 147.8076},
#  {'Item_Identifier': 'FDY45',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.026015519,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 255.8356,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 2543.356},
#  {'Item_Identifier': 'FDC46',
#   'Item_Weight': 17.7,
#   'Item_Fat_Content': 'LF',
#   'Item_Visibility': 0.195068226,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 185.4266,
#   'Outlet_Identifier': 'OUT010',
#   'Outlet_Establishment_Year': 1998,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 184.4266},
#  {'Item_Identifier': 'FDH19',
#   'Item_Weight': 19.35,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.033082215,
#   'Item_Type': 'Meat',
#   'Item_MRP': 172.5738,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 4865.6664},
#  {'Item_Identifier': 'FDZ03',
#   'Item_Weight': 13.65,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.078946455,
#   'Item_Type': 'Dairy',
#   'Item_MRP': 186.024,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1118.544},
#  {'Item_Identifier': 'DRH37',
#   'Item_Weight': 17.6,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.041700756,
#   'Item_Type': 'Soft Drinks',
#   'Item_MRP': 164.8526,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2302.3364},
#  {'Item_Identifier': 'NCI17',
#   'Item_Weight': 8.645,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.143422643,
#   'Item_Type': 'Health and Hygiene',
#   'Item_MRP': 95.841,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2027.361},
#  {'Item_Identifier': 'FDJ58',
#   'Item_Weight': 15.6,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.105296072,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 170.1764,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 3435.528},
#  {'Item_Identifier': 'FDL12',
#   'Item_Weight': 15.85,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.121531501,
#   'Item_Type': 'Baking Goods',
#   'Item_MRP': 59.222,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 599.22},
#  {'Item_Identifier': 'FDH35',
#   'Item_Weight': 18.25,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.0,
#   'Item_Type': 'Starchy Foods',
#   'Item_MRP': 164.7526,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 4604.6728},
#  {'Item_Identifier': 'FDG02',
#   'Item_Weight': 7.855,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.011324862,
#   'Item_Type': 'Canned',
#   'Item_MRP': 189.6188,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2285.0256},
#  {'Item_Identifier': 'NCZ18',
#   'Item_Weight': 7.825,
#   'Item_Fat_Content': 'low fat',
#   'Item_Visibility': 0.186357148,
#   'Item_Type': 'Household',
#   'Item_MRP': 254.3698,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 5580.7356},
#  {'Item_Identifier': 'FDC29',
#   'Item_Weight': 8.39,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.024205661,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 114.0176,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2290.352},
#  {'Item_Identifier': 'FDQ10',
#   'Item_Weight': 12.85,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.033230816,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 172.3422,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1207.0954},
#  {'Item_Identifier': 'FDN48',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.113720344,
#   'Item_Type': 'Baking Goods',
#   'Item_MRP': 89.9804,
#   'Outlet_Identifier': 'OUT019',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 643.1628},
#  {'Item_Identifier': 'FDL04',
#   'Item_Weight': 19.0,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.112556507,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 104.9622,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1587.933},
#  {'Item_Identifier': 'FDV25',
#   'Item_Weight': 5.905,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.0,
#   'Item_Type': 'Canned',
#   'Item_MRP': 222.5456,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 5305.0944},
#  {'Item_Identifier': 'FDD58',
#   'Item_Weight': 7.76,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.059352241,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 101.87,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1697.79},
#  {'Item_Identifier': 'FDN04',
#   'Item_Weight': 11.8,
#   'Item_Fat_Content': 'reg',
#   'Item_Visibility': 0.014087057,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 180.3344,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1427.4752},
#  {'Item_Identifier': 'FDV45',
#   'Item_Weight': 16.75,
#   'Item_Fat_Content': 'low fat',
#   'Item_Visibility': 0.045230944,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 187.9556,
#   'Outlet_Identifier': 'OUT018',
#   'Outlet_Establishment_Year': 2009,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type2',
#   'Item_Outlet_Sales': 4693.89},
#  {'Item_Identifier': 'NCL18',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.293417759,
#   'Item_Type': 'Household',
#   'Item_MRP': 194.6136,
#   'Outlet_Identifier': 'OUT019',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 583.2408},
#  {'Item_Identifier': 'FDR12',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.031382044,
#   'Item_Type': 'Baking Goods',
#   'Item_MRP': 171.3764,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 3091.9752},
#  {'Item_Identifier': 'FDG20',
#   'Item_Weight': 15.5,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.12639886,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 177.0028,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2479.4392},
#  {'Item_Identifier': 'FDZ55',
#   'Item_Weight': 6.055,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.025403898,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 160.992,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2716.464},
#  {'Item_Identifier': 'FDQ49',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.039057677,
#   'Item_Type': 'Breakfast',
#   'Item_MRP': 155.963,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 3285.723},
#  {'Item_Identifier': 'FDN33',
#   'Item_Weight': 6.305,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.123115764,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 95.6436,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 661.8052},
#  {'Item_Identifier': 'FDN27',
#   'Item_Weight': 20.85,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.039624006,
#   'Item_Type': 'Meat',
#   'Item_MRP': 117.2808,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1523.3504},
#  {'Item_Identifier': 'FDW20',
#   'Item_Weight': 20.75,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.040421193,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 122.173,
#   'Outlet_Identifier': 'OUT010',
#   'Outlet_Establishment_Year': 1998,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 369.519},
#  {'Item_Identifier': 'DRG27',
#   'Item_Weight': 8.895,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.105274111,
#   'Item_Type': 'Dairy',
#   'Item_MRP': 39.9138,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 690.4346},
#  {'Item_Identifier': 'DRI25',
#   'Item_Weight': 19.6,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.033970195,
#   'Item_Type': 'Soft Drinks',
#   'Item_MRP': 55.1614,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1381.535},
#  {'Item_Identifier': 'FDA44',
#   'Item_Weight': 19.7,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.053212652,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 57.893,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 622.523},
#  {'Item_Identifier': 'NCR17',
#   'Item_Weight': 9.8,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.024378706,
#   'Item_Type': 'Health and Hygiene',
#   'Item_MRP': 114.5492,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1274.3412},
#  {'Item_Identifier': 'FDU04',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.009714595,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 120.0414,
#   'Outlet_Identifier': 'OUT019',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 487.3656},
#  {'Item_Identifier': 'FDF41',
#   'Item_Weight': 12.15,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.131383762,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 246.046,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1231.73},
#  {'Item_Identifier': 'FDB56',
#   'Item_Weight': 8.75,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.07461309,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 187.4556,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 3755.112},
#  {'Item_Identifier': 'NCP18',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.028459761,
#   'Item_Type': 'Household',
#   'Item_MRP': 149.9708,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 4363.6532},
#  {'Item_Identifier': 'FDB56',
#   'Item_Weight': 8.75,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.074627201,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 187.8556,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1314.2892},
#  {'Item_Identifier': 'FDT28',
#   'Item_Weight': 13.3,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.063695084,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 151.0708,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1805.6496},
#  {'Item_Identifier': 'FDD10',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.045797829,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 178.5344,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 2854.9504},
#  {'Item_Identifier': 'FDW57',
#   'Item_Weight': 8.31,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.115857223,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 179.1028,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 3896.2616},
#  {'Item_Identifier': 'DRB48',
#   'Item_Weight': 16.75,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.024832806,
#   'Item_Type': 'Soft Drinks',
#   'Item_MRP': 38.7822,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 667.7974},
#  {'Item_Identifier': 'FDP09',
#   'Item_Weight': 19.75,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.034027909,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 212.0902,
#   'Outlet_Identifier': 'OUT018',
#   'Outlet_Establishment_Year': 2009,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type2',
#   'Item_Outlet_Sales': 3185.853},
#  {'Item_Identifier': 'FDH14',
#   'Item_Weight': 17.1,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.0467696,
#   'Item_Type': 'Canned',
#   'Item_MRP': 141.1838,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2247.7408},
#  {'Item_Identifier': 'FDA47',
#   'Item_Weight': 10.5,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.116576702,
#   'Item_Type': 'Baking Goods',
#   'Item_MRP': 163.121,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1794.331},
#  {'Item_Identifier': 'FDG12',
#   'Item_Weight': 6.635,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.0,
#   'Item_Type': 'Baking Goods',
#   'Item_MRP': 121.3098,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2530.7058},
#  {'Item_Identifier': 'DRE60',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'low fat',
#   'Item_Visibility': 0.278974075,
#   'Item_Type': 'Soft Drinks',
#   'Item_MRP': 225.372,
#   'Outlet_Identifier': 'OUT019',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 679.116},
#  {'Item_Identifier': 'DRK49',
#   'Item_Weight': 14.15,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.035913805,
#   'Item_Type': 'Soft Drinks',
#   'Item_MRP': 41.4138,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 812.276},
#  {'Item_Identifier': 'FDD03',
#   'Item_Weight': 13.3,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.079806266,
#   'Item_Type': 'Dairy',
#   'Item_MRP': 232.53,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 699.09},
#  {'Item_Identifier': 'FDS52',
#   'Item_Weight': 8.89,
#   'Item_Fat_Content': 'low fat',
#   'Item_Visibility': 0.005505481,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 102.4016,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2732.4432},
#  {'Item_Identifier': 'FDW39',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.064625342,
#   'Item_Type': 'Meat',
#   'Item_MRP': 176.937,
#   'Outlet_Identifier': 'OUT019',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 176.437},
#  {'Item_Identifier': 'FDX34',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.071636937,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 121.7098,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 4097.3332},
#  {'Item_Identifier': 'FDV11',
#   'Item_Weight': 9.1,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.0,
#   'Item_Type': 'Breads',
#   'Item_MRP': 173.2054,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 3151.8972},
#  {'Item_Identifier': 'FDD17',
#   'Item_Weight': 7.5,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.032677678,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 239.0906,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 5942.265},
#  {'Item_Identifier': 'FDZ16',
#   'Item_Weight': 16.85,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.160760054,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 192.4478,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 4843.695},
#  {'Item_Identifier': 'FDZ46',
#   'Item_Weight': 7.485,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.06911065,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 109.0228,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2542.0244},
#  {'Item_Identifier': 'DRA12',
#   'Item_Weight': 11.6,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.041177505,
#   'Item_Type': 'Soft Drinks',
#   'Item_MRP': 140.3154,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2552.6772},
#  {'Item_Identifier': 'FDY58',
#   'Item_Weight': 11.65,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.040081193,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 227.0694,
#   'Outlet_Identifier': 'OUT018',
#   'Outlet_Establishment_Year': 2009,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type2',
#   'Item_Outlet_Sales': 1141.847},
#  {'Item_Identifier': 'NCF19',
#   'Item_Weight': 13.0,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.035307322,
#   'Item_Type': 'Household',
#   'Item_MRP': 47.5034,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 680.4476},
#  {'Item_Identifier': 'DRJ13',
#   'Item_Weight': 12.65,
#   'Item_Fat_Content': 'LF',
#   'Item_Visibility': 0.063017847,
#   'Item_Type': 'Soft Drinks',
#   'Item_MRP': 159.0578,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2085.9514},
#  {'Item_Identifier': 'FDB14',
#   'Item_Weight': 20.25,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.171938781,
#   'Item_Type': 'Canned',
#   'Item_MRP': 92.512,
#   'Outlet_Identifier': 'OUT010',
#   'Outlet_Establishment_Year': 1998,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 186.424},
#  {'Item_Identifier': 'FDJ38',
#   'Item_Weight': 8.6,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.040197932,
#   'Item_Type': 'Canned',
#   'Item_MRP': 190.153,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 3036.048},
#  {'Item_Identifier': 'FDW11',
#   'Item_Weight': 12.6,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.049058014,
#   'Item_Type': 'Breads',
#   'Item_MRP': 62.7194,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 866.8716},
#  {'Item_Identifier': 'FDL40',
#   'Item_Weight': 17.7,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.01161096,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 95.041,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 868.869},
#  {'Item_Identifier': 'DRI49',
#   'Item_Weight': 14.15,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.183507295,
#   'Item_Type': 'Soft Drinks',
#   'Item_MRP': 82.4276,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1137.1864},
#  {'Item_Identifier': 'FDV38',
#   'Item_Weight': 19.25,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.102349519,
#   'Item_Type': 'Dairy',
#   'Item_MRP': 52.7956,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
# ...
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1798.9916},
#  {'Item_Identifier': 'FDO13',
#   'Item_Weight': 7.865,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.061405051,
#   'Item_Type': 'Breakfast',
#   'Item_MRP': 166.3526,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1973.4312},
#  {'Item_Identifier': 'FDU25',
#   'Item_Weight': 12.35,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.026676216,
#   'Item_Type': 'Canned',
#   'Item_MRP': 57.0246,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1737.738},
#  {'Item_Identifier': 'NCK54',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.029380407,
#   'Item_Type': 'Household',
#   'Item_MRP': 114.715,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 1864.24},
#  {'Item_Identifier': 'FDZ56',
#   'Item_Weight': 16.25,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.025715562,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 168.1474,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1516.0266},
#  {'Item_Identifier': 'NCL55',
#   'Item_Weight': 12.15,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.065026434,
#   'Item_Type': 'Others',
#   'Item_MRP': 253.704,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 5060.08},
#  {'Item_Identifier': 'FDD59',
#   'Item_Weight': 10.5,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.066315023,
#   'Item_Type': 'Starchy Foods',
#   'Item_MRP': 78.296,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2157.192},
#  {'Item_Identifier': 'FDJ55',
#   'Item_Weight': 12.8,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.023664054,
#   'Item_Type': 'Meat',
#   'Item_MRP': 226.0404,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 5400.9696},
#  {'Item_Identifier': 'FDA45',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.154627247,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 177.637,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 5469.547},
#  {'Item_Identifier': 'DRF23',
#   'Item_Weight': 4.61,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.205294827,
#   'Item_Type': 'Hard Drinks',
#   'Item_MRP': 172.8396,
#   'Outlet_Identifier': 'OUT010',
#   'Outlet_Establishment_Year': 1998,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 174.4396},
#  {'Item_Identifier': 'FDT49',
#   'Item_Weight': 7.0,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.152261999,
#   'Item_Type': 'Canned',
#   'Item_MRP': 105.728,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1278.336},
#  {'Item_Identifier': 'NCO17',
#   'Item_Weight': 10.0,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.0,
#   'Item_Type': 'Health and Hygiene',
#   'Item_MRP': 120.644,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1917.504},
#  {'Item_Identifier': 'FDH22',
#   'Item_Weight': 6.405,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.136275173,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 128.1678,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1017.3424},
#  {'Item_Identifier': 'FDT34',
#   'Item_Weight': 9.3,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.174621343,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 104.2964,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1998.7316},
#  {'Item_Identifier': 'FDB39',
#   'Item_Weight': 11.6,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.038597077,
#   'Item_Type': 'Dairy',
#   'Item_MRP': 57.9272,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 615.1992},
#  {'Item_Identifier': 'FDQ22',
#   'Item_Weight': 16.75,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.029799965,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 39.1822,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 314.2576},
#  {'Item_Identifier': 'NCN43',
#   'Item_Weight': 12.15,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.011314423,
#   'Item_Type': 'Others',
#   'Item_MRP': 122.973,
#   'Outlet_Identifier': 'OUT010',
#   'Outlet_Establishment_Year': 1998,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 123.173},
#  {'Item_Identifier': 'FDG57',
#   'Item_Weight': 14.7,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.072410764,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 48.2034,
#   'Outlet_Identifier': 'OUT049',
#   'Outlet_Establishment_Year': 1999,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1020.6714},
#  {'Item_Identifier': 'FDR20',
#   'Item_Weight': 20.0,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.028118435,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 46.7744,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1222.4088},
#  {'Item_Identifier': 'FDU22',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.163350221,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 120.2124,
#   'Outlet_Identifier': 'OUT019',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 474.0496},
#  {'Item_Identifier': 'NCC43',
#   'Item_Weight': 7.39,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.093307713,
#   'Item_Type': 'Household',
#   'Item_MRP': 250.9066,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1506.0396},
#  {'Item_Identifier': 'FDP01',
#   'Item_Weight': 20.75,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.105994654,
#   'Item_Type': 'Breakfast',
#   'Item_MRP': 150.5682,
#   'Outlet_Identifier': 'OUT010',
#   'Outlet_Establishment_Year': 1998,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 762.341},
#  {'Item_Identifier': 'FDF52',
#   'Item_Weight': 9.3,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.067055339,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 184.2292,
#   'Outlet_Identifier': 'OUT018',
#   'Outlet_Establishment_Year': 2009,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type2',
#   'Item_Outlet_Sales': 1277.0044},
#  {'Item_Identifier': 'FDZ33',
#   'Item_Weight': 10.195,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.107376743,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 147.6076,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 3547.3824},
#  {'Item_Identifier': 'FDP48',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.043810028,
#   'Item_Type': 'Baking Goods',
#   'Item_MRP': 181.395,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 6042.135},
#  {'Item_Identifier': 'FDW56',
#   'Item_Weight': 7.68,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.118672537,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 192.2162,
#   'Outlet_Identifier': 'OUT010',
#   'Outlet_Establishment_Year': 1998,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 384.8324},
#  {'Item_Identifier': 'FDC26',
#   'Item_Weight': 10.195,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.126897925,
#   'Item_Type': 'Canned',
#   'Item_MRP': 110.6886,
#   'Outlet_Identifier': 'OUT018',
#   'Outlet_Establishment_Year': 2009,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type2',
#   'Item_Outlet_Sales': 1223.0746},
#  {'Item_Identifier': 'FDF34',
#   'Item_Weight': 9.3,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.014076503,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 200.0084,
#   'Outlet_Identifier': 'OUT018',
#   'Outlet_Establishment_Year': 2009,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type2',
#   'Item_Outlet_Sales': 2182.4924},
#  {'Item_Identifier': 'FDJ33',
#   'Item_Weight': 8.895,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.088305478,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 123.473,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1478.076},
#  {'Item_Identifier': 'FDD04',
#   'Item_Weight': 16.0,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.090153756,
#   'Item_Type': 'Dairy',
#   'Item_MRP': 143.2154,
#   'Outlet_Identifier': 'OUT045',
#   'Outlet_Establishment_Year': 2002,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1418.154},
#  {'Item_Identifier': 'NCJ31',
#   'Item_Weight': 19.2,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.182501773,
#   'Item_Type': 'Others',
#   'Item_MRP': 239.2196,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 5061.4116},
#  {'Item_Identifier': 'FDO57',
#   'Item_Weight': 20.75,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.108710162,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 161.7578,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2888.2404},
#  {'Item_Identifier': 'FDM36',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.058446424,
#   'Item_Type': 'Baking Goods',
#   'Item_MRP': 172.1422,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 5518.1504},
#  {'Item_Identifier': 'NCY05',
#   'Item_Weight': 13.5,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.054990009,
#   'Item_Type': 'Health and Hygiene',
#   'Item_MRP': 35.2874,
#   'Outlet_Identifier': 'OUT046',
#   'Outlet_Establishment_Year': 1997,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 1',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 741.0354},
#  {'Item_Identifier': 'FDS44',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.15528831,
#   'Item_Type': 'Fruits and Vegetables',
#   'Item_MRP': 241.7538,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 9133.4444},
#  {'Item_Identifier': 'FDZ39',
#   'Item_Weight': 19.7,
#   'Item_Fat_Content': 'Regular',
#   'Item_Visibility': 0.018021361,
#   'Item_Type': 'Meat',
#   'Item_MRP': 101.199,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1857.582},
#  {'Item_Identifier': 'NCM31',
#   'Item_Weight': 6.095,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.0816559,
#   'Item_Type': 'Others',
#   'Item_MRP': 143.3154,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2836.308},
#  {'Item_Identifier': 'DRK11',
#   'Item_Weight': 8.21,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.010755465,
#   'Item_Type': 'Hard Drinks',
#   'Item_MRP': 150.8392,
#   'Outlet_Identifier': 'OUT013',
#   'Outlet_Establishment_Year': 1987,
#   'Outlet_Size': 'High',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 2982.784},
#  {'Item_Identifier': 'FDO34',
#   'Item_Weight': 17.7,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.050111641,
#   'Item_Type': 'Snack Foods',
#   'Item_MRP': 165.9816,
#   'Outlet_Identifier': 'OUT010',
#   'Outlet_Establishment_Year': 1998,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Grocery Store',
#   'Item_Outlet_Sales': 167.7816},
#  {'Item_Identifier': 'NCL30',
#   'Item_Weight': 18.1,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.048931174,
#   'Item_Type': 'Household',
#   'Item_MRP': 127.3336,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 1150.5024},
#  {'Item_Identifier': 'FDK28',
#   'Item_Weight': 5.695,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.065960909,
#   'Item_Type': 'Frozen Foods',
#   'Item_MRP': 259.2646,
#   'Outlet_Identifier': 'OUT017',
#   'Outlet_Establishment_Year': 2007,
#   'Outlet_Size': nan,
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 9275.9256},
#  {'Item_Identifier': 'DRJ39',
#   'Item_Weight': 20.25,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.036319195,
#   'Item_Type': 'Dairy',
#   'Item_MRP': 219.3482,
#   'Outlet_Identifier': 'OUT035',
#   'Outlet_Establishment_Year': 2004,
#   'Outlet_Size': 'Small',
#   'Outlet_Location_Type': 'Tier 2',
#   'Outlet_Type': 'Supermarket Type1',
#   'Item_Outlet_Sales': 5038.1086},
#  {'Item_Identifier': 'NCP06',
#   'Item_Weight': nan,
#   'Item_Fat_Content': 'Low Fat',
#   'Item_Visibility': 0.039055756,
#   'Item_Type': 'Household',
#   'Item_MRP': 152.3366,
#   'Outlet_Identifier': 'OUT027',
#   'Outlet_Establishment_Year': 1985,
#   'Outlet_Size': 'Medium',
#   'Outlet_Location_Type': 'Tier 3',
#   'Outlet_Type': 'Supermarket Type3',
#   'Item_Outlet_Sales': 2115.9124},
#  ...]

# %%
len(data)
# Out:
# 8523

# %%
DB_NAME = "Store_Sales"
COLLECTION_NAME = "sales_data"
CONNECTION_URL = "......."

# %%
import pymongo

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

rec = collection.insert_many(data)

# %%
records = collection.find()
records

# %%
for i, j in enumerate(records):
    print(f"{i}: {j}")
# Out:
# 0: {'_id': ObjectId('66fd0caa72762b446c953cf0'), 'Item_Identifier': 'FDA15', 'Item_Weight': 9.3, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.016047301, 'Item_Type': 'Dairy', 'Item_MRP': 249.8092, 'Outlet_Identifier': 'OUT049', 'Outlet_Establishment_Year': 1999, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 3735.138}
# 1: {'_id': ObjectId('66fd0caa72762b446c953cf1'), 'Item_Identifier': 'DRC01', 'Item_Weight': 5.92, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.019278216, 'Item_Type': 'Soft Drinks', 'Item_MRP': 48.2692, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 443.4228}
# 2: {'_id': ObjectId('66fd0caa72762b446c953cf2'), 'Item_Identifier': 'FDN15', 'Item_Weight': 17.5, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.016760075, 'Item_Type': 'Meat', 'Item_MRP': 141.618, 'Outlet_Identifier': 'OUT049', 'Outlet_Establishment_Year': 1999, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2097.27}
# 3: {'_id': ObjectId('66fd0caa72762b446c953cf3'), 'Item_Identifier': 'FDX07', 'Item_Weight': 19.2, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.0, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 182.095, 'Outlet_Identifier': 'OUT010', 'Outlet_Establishment_Year': 1998, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 732.38}
# 4: {'_id': ObjectId('66fd0caa72762b446c953cf4'), 'Item_Identifier': 'NCD19', 'Item_Weight': 8.93, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.0, 'Item_Type': 'Household', 'Item_MRP': 53.8614, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 994.7052}
# 5: {'_id': ObjectId('66fd0caa72762b446c953cf5'), 'Item_Identifier': 'FDP36', 'Item_Weight': 10.395, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.0, 'Item_Type': 'Baking Goods', 'Item_MRP': 51.4008, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 556.6088}
# 6: {'_id': ObjectId('66fd0caa72762b446c953cf6'), 'Item_Identifier': 'FDO10', 'Item_Weight': 13.65, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.012741089, 'Item_Type': 'Snack Foods', 'Item_MRP': 57.6588, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 343.5528}
# 7: {'_id': ObjectId('66fd0caa72762b446c953cf7'), 'Item_Identifier': 'FDP10', 'Item_Weight': nan, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.127469857, 'Item_Type': 'Snack Foods', 'Item_MRP': 107.7622, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 4022.7636}
# 8: {'_id': ObjectId('66fd0caa72762b446c953cf8'), 'Item_Identifier': 'FDH17', 'Item_Weight': 16.2, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.016687114, 'Item_Type': 'Frozen Foods', 'Item_MRP': 96.9726, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1076.5986}
# 9: {'_id': ObjectId('66fd0caa72762b446c953cf9'), 'Item_Identifier': 'FDU28', 'Item_Weight': 19.2, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.09444959, 'Item_Type': 'Frozen Foods', 'Item_MRP': 187.8214, 'Outlet_Identifier': 'OUT017', 'Outlet_Establishment_Year': 2007, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 4710.535}
# 10: {'_id': ObjectId('66fd0caa72762b446c953cfa'), 'Item_Identifier': 'FDY07', 'Item_Weight': 11.8, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.0, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 45.5402, 'Outlet_Identifier': 'OUT049', 'Outlet_Establishment_Year': 1999, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1516.0266}
# 11: {'_id': ObjectId('66fd0caa72762b446c953cfb'), 'Item_Identifier': 'FDA03', 'Item_Weight': 18.5, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.045463773, 'Item_Type': 'Dairy', 'Item_MRP': 144.1102, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2187.153}
# 12: {'_id': ObjectId('66fd0caa72762b446c953cfc'), 'Item_Identifier': 'FDX32', 'Item_Weight': 15.1, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.1000135, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 145.4786, 'Outlet_Identifier': 'OUT049', 'Outlet_Establishment_Year': 1999, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1589.2646}
# 13: {'_id': ObjectId('66fd0caa72762b446c953cfd'), 'Item_Identifier': 'FDS46', 'Item_Weight': 17.6, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.047257328, 'Item_Type': 'Snack Foods', 'Item_MRP': 119.6782, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2145.2076}
# 14: {'_id': ObjectId('66fd0caa72762b446c953cfe'), 'Item_Identifier': 'FDF32', 'Item_Weight': 16.35, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.0680243, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 196.4426, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1977.426}
# 15: {'_id': ObjectId('66fd0caa72762b446c953cff'), 'Item_Identifier': 'FDP49', 'Item_Weight': 9.0, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.069088961, 'Item_Type': 'Breakfast', 'Item_MRP': 56.3614, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1547.3192}
# 16: {'_id': ObjectId('66fd0caa72762b446c953d00'), 'Item_Identifier': 'NCB42', 'Item_Weight': 11.8, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.008596051, 'Item_Type': 'Health and Hygiene', 'Item_MRP': 115.3492, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 1621.8888}
# 17: {'_id': ObjectId('66fd0caa72762b446c953d01'), 'Item_Identifier': 'FDP49', 'Item_Weight': 9.0, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.069196376, 'Item_Type': 'Breakfast', 'Item_MRP': 54.3614, 'Outlet_Identifier': 'OUT049', 'Outlet_Establishment_Year': 1999, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 718.3982}
# 18: {'_id': ObjectId('66fd0caa72762b446c953d02'), 'Item_Identifier': 'DRI11', 'Item_Weight': nan, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.034237682, 'Item_Type': 'Hard Drinks', 'Item_MRP': 113.2834, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 2303.668}
# 19: {'_id': ObjectId('66fd0caa72762b446c953d03'), 'Item_Identifier': 'FDU02', 'Item_Weight': 13.35, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.10249212, 'Item_Type': 'Dairy', 'Item_MRP': 230.5352, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2748.4224}
# 20: {'_id': ObjectId('66fd0caa72762b446c953d04'), 'Item_Identifier': 'FDN22', 'Item_Weight': 18.85, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.138190277, 'Item_Type': 'Snack Foods', 'Item_MRP': 250.8724, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 3775.086}
# 21: {'_id': ObjectId('66fd0caa72762b446c953d05'), 'Item_Identifier': 'FDW12', 'Item_Weight': nan, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.035399923, 'Item_Type': 'Baking Goods', 'Item_MRP': 144.5444, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 4064.0432}
# 22: {'_id': ObjectId('66fd0caa72762b446c953d06'), 'Item_Identifier': 'NCB30', 'Item_Weight': 14.6, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.025698134, 'Item_Type': 'Household', 'Item_MRP': 196.5084, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1587.2672}
# 23: {'_id': ObjectId('66fd0caa72762b446c953d07'), 'Item_Identifier': 'FDC37', 'Item_Weight': nan, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.057556998, 'Item_Type': 'Baking Goods', 'Item_MRP': 107.6938, 'Outlet_Identifier': 'OUT019', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 214.3876}
# 24: {'_id': ObjectId('66fd0caa72762b446c953d08'), 'Item_Identifier': 'FDR28', 'Item_Weight': 13.85, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.025896485, 'Item_Type': 'Frozen Foods', 'Item_MRP': 165.021, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 4078.025}
# 25: {'_id': ObjectId('66fd0caa72762b446c953d09'), 'Item_Identifier': 'NCD06', 'Item_Weight': 13.0, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.099887103, 'Item_Type': 'Household', 'Item_MRP': 45.906, 'Outlet_Identifier': 'OUT017', 'Outlet_Establishment_Year': 2007, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 838.908}
# 26: {'_id': ObjectId('66fd0caa72762b446c953d0a'), 'Item_Identifier': 'FDV10', 'Item_Weight': 7.645, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.066693437, 'Item_Type': 'Snack Foods', 'Item_MRP': 42.3112, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1065.28}
# 27: {'_id': ObjectId('66fd0caa72762b446c953d0b'), 'Item_Identifier': 'DRJ59', 'Item_Weight': 11.65, 'Item_Fat_Content': 'low fat', 'Item_Visibility': 0.019356132, 'Item_Type': 'Hard Drinks', 'Item_MRP': 39.1164, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 308.9312}
# 28: {'_id': ObjectId('66fd0caa72762b446c953d0c'), 'Item_Identifier': 'FDE51', 'Item_Weight': 5.925, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.161466534, 'Item_Type': 'Dairy', 'Item_MRP': 45.5086, 'Outlet_Identifier': 'OUT010', 'Outlet_Establishment_Year': 1998, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 178.4344}
# 29: {'_id': ObjectId('66fd0caa72762b446c953d0d'), 'Item_Identifier': 'FDC14', 'Item_Weight': nan, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.072221801, 'Item_Type': 'Canned', 'Item_MRP': 43.6454, 'Outlet_Identifier': 'OUT019', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 125.8362}
# 30: {'_id': ObjectId('66fd0caa72762b446c953d0e'), 'Item_Identifier': 'FDV38', 'Item_Weight': 19.25, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.170348551, 'Item_Type': 'Dairy', 'Item_MRP': 55.7956, 'Outlet_Identifier': 'OUT010', 'Outlet_Establishment_Year': 1998, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 163.7868}
# 31: {'_id': ObjectId('66fd0caa72762b446c953d0f'), 'Item_Identifier': 'NCS17', 'Item_Weight': 18.6, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.080829372, 'Item_Type': 'Health and Hygiene', 'Item_MRP': 96.4436, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 2741.7644}
# 32: {'_id': ObjectId('66fd0caa72762b446c953d10'), 'Item_Identifier': 'FDP33', 'Item_Weight': 18.7, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.0, 'Item_Type': 'Snack Foods', 'Item_MRP': 256.6672, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 3068.0064}
# 33: {'_id': ObjectId('66fd0caa72762b446c953d11'), 'Item_Identifier': 'FDO23', 'Item_Weight': 17.85, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.0, 'Item_Type': 'Breads', 'Item_MRP': 93.1436, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2174.5028}
# 34: {'_id': ObjectId('66fd0caa72762b446c953d12'), 'Item_Identifier': 'DRH01', 'Item_Weight': 17.5, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.097904029, 'Item_Type': 'Soft Drinks', 'Item_MRP': 174.8738, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2085.2856}
# 35: {'_id': ObjectId('66fd0caa72762b446c953d13'), 'Item_Identifier': 'NCX29', 'Item_Weight': 10.0, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.089291137, 'Item_Type': 'Health and Hygiene', 'Item_MRP': 146.7102, 'Outlet_Identifier': 'OUT049', 'Outlet_Establishment_Year': 1999, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 3791.0652}
# 36: {'_id': ObjectId('66fd0caa72762b446c953d14'), 'Item_Identifier': 'FDV20', 'Item_Weight': nan, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.059511812, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 128.0678, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 2797.6916}
# 37: {'_id': ObjectId('66fd0caa72762b446c953d15'), 'Item_Identifier': 'DRZ11', 'Item_Weight': 8.85, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.113123893, 'Item_Type': 'Soft Drinks', 'Item_MRP': 122.5388, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 1609.9044}
# 38: {'_id': ObjectId('66fd0caa72762b446c953d16'), 'Item_Identifier': 'FDX10', 'Item_Weight': nan, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.123111453, 'Item_Type': 'Snack Foods', 'Item_MRP': 36.9874, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 388.1614}
# 39: {'_id': ObjectId('66fd0caa72762b446c953d17'), 'Item_Identifier': 'FDB34', 'Item_Weight': nan, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.026480954, 'Item_Type': 'Snack Foods', 'Item_MRP': 87.6198, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 2180.495}
# 40: {'_id': ObjectId('66fd0caa72762b446c953d18'), 'Item_Identifier': 'FDU02', 'Item_Weight': 13.35, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.102511504, 'Item_Type': 'Dairy', 'Item_MRP': 230.6352, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 3435.528}
# 41: {'_id': ObjectId('66fd0caa72762b446c953d19'), 'Item_Identifier': 'FDK43', 'Item_Weight': 9.8, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.02681843, 'Item_Type': 'Meat', 'Item_MRP': 126.002, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2150.534}
# 42: {'_id': ObjectId('66fd0caa72762b446c953d1a'), 'Item_Identifier': 'FDA46', 'Item_Weight': 13.6, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.117818348, 'Item_Type': 'Snack Foods', 'Item_MRP': 192.9136, 'Outlet_Identifier': 'OUT049', 'Outlet_Establishment_Year': 1999, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2527.3768}
# 43: {'_id': ObjectId('66fd0caa72762b446c953d1b'), 'Item_Identifier': 'FDC02', 'Item_Weight': 21.35, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.069102831, 'Item_Type': 'Canned', 'Item_MRP': 259.9278, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 6768.5228}
# 44: {'_id': ObjectId('66fd0caa72762b446c953d1c'), 'Item_Identifier': 'FDL50', 'Item_Weight': 12.15, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.042277867, 'Item_Type': 'Canned', 'Item_MRP': 126.5046, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 373.5138}
# 45: {'_id': ObjectId('66fd0caa72762b446c953d1d'), 'Item_Identifier': 'FDM39', 'Item_Weight': 6.42, 'Item_Fat_Content': 'LF', 'Item_Visibility': 0.089498926, 'Item_Type': 'Dairy', 'Item_MRP': 178.1002, 'Outlet_Identifier': 'OUT010', 'Outlet_Establishment_Year': 1998, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 358.2004}
# 46: {'_id': ObjectId('66fd0caa72762b446c953d1e'), 'Item_Identifier': 'NCP05', 'Item_Weight': 19.6, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.0, 'Item_Type': 'Health and Hygiene', 'Item_MRP': 153.3024, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2428.8384}
# 47: {'_id': ObjectId('66fd0caa72762b446c953d1f'), 'Item_Identifier': 'FDV49', 'Item_Weight': 10.0, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.025879577, 'Item_Type': 'Canned', 'Item_MRP': 265.2226, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 5815.0972}
# 48: {'_id': ObjectId('66fd0caa72762b446c953d20'), 'Item_Identifier': 'FDL12', 'Item_Weight': 15.85, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.121632721, 'Item_Type': 'Baking Goods', 'Item_MRP': 60.622, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2576.646}
# 49: {'_id': ObjectId('66fd0caa72762b446c953d21'), 'Item_Identifier': 'FDS02', 'Item_Weight': nan, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.255394896, 'Item_Type': 'Dairy', 'Item_MRP': 196.8794, 'Outlet_Identifier': 'OUT019', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 780.3176}
# 50: {'_id': ObjectId('66fd0caa72762b446c953d22'), 'Item_Identifier': 'NCL17', 'Item_Weight': 7.39, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.067779712, 'Item_Type': 'Health and Hygiene', 'Item_MRP': 143.8812, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 3134.5864}
# 51: {'_id': ObjectId('66fd0caa72762b446c953d23'), 'Item_Identifier': 'FDM40', 'Item_Weight': 10.195, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.159803853, 'Item_Type': 'Frozen Foods', 'Item_MRP': 141.5154, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 850.8924}
# 52: {'_id': ObjectId('66fd0caa72762b446c953d24'), 'Item_Identifier': 'FDR13', 'Item_Weight': 9.895, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.028696932, 'Item_Type': 'Canned', 'Item_MRP': 117.0492, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 810.9444}
# 53: {'_id': ObjectId('66fd0caa72762b446c953d25'), 'Item_Identifier': 'FDA43', 'Item_Weight': 10.895, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.065041581, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 196.3794, 'Outlet_Identifier': 'OUT017', 'Outlet_Establishment_Year': 2007, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 3121.2704}
# 54: {'_id': ObjectId('66fd0caa72762b446c953d26'), 'Item_Identifier': 'NCP18', 'Item_Weight': 12.15, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.028760013, 'Item_Type': 'Household', 'Item_MRP': 151.4708, 'Outlet_Identifier': 'OUT017', 'Outlet_Establishment_Year': 2007, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 4815.0656}
# 55: {'_id': ObjectId('66fd0caa72762b446c953d27'), 'Item_Identifier': 'FDK21', 'Item_Weight': 7.905, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.010053105, 'Item_Type': 'Snack Foods', 'Item_MRP': 249.0408, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 6258.52}
# 56: {'_id': ObjectId('66fd0caa72762b446c953d28'), 'Item_Identifier': 'NCX54', 'Item_Weight': 9.195, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.048157338, 'Item_Type': 'Household', 'Item_MRP': 106.1622, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2117.244}
# 57: {'_id': ObjectId('66fd0caa72762b446c953d29'), 'Item_Identifier': 'DRK35', 'Item_Weight': 8.365, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.071958197, 'Item_Type': 'Hard Drinks', 'Item_MRP': 38.0506, 'Outlet_Identifier': 'OUT049', 'Outlet_Establishment_Year': 1999, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 796.9626}
# 58: {'_id': ObjectId('66fd0caa72762b446c953d2a'), 'Item_Identifier': 'FDY21', 'Item_Weight': 15.1, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.173481304, 'Item_Type': 'Snack Foods', 'Item_MRP': 194.511, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 4910.275}
# 59: {'_id': ObjectId('66fd0caa72762b446c953d2b'), 'Item_Identifier': 'FDI26', 'Item_Weight': nan, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.061082177, 'Item_Type': 'Canned', 'Item_MRP': 180.0344, 'Outlet_Identifier': 'OUT019', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 892.172}
# 60: {'_id': ObjectId('66fd0caa72762b446c953d2c'), 'Item_Identifier': 'FDM20', 'Item_Weight': 10.0, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.0, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 246.9144, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 3185.1872}
# 61: {'_id': ObjectId('66fd0caa72762b446c953d2d'), 'Item_Identifier': 'FDV27', 'Item_Weight': 7.97, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.040071131, 'Item_Type': 'Meat', 'Item_MRP': 87.3514, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1062.6168}
# 62: {'_id': ObjectId('66fd0caa72762b446c953d2e'), 'Item_Identifier': 'FDF09', 'Item_Weight': nan, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.012090074, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 38.2848, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 484.7024}
# 63: {'_id': ObjectId('66fd0caa72762b446c953d2f'), 'Item_Identifier': 'FDY40', 'Item_Weight': nan, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.15028599, 'Item_Type': 'Frozen Foods', 'Item_MRP': 51.0692, 'Outlet_Identifier': 'OUT019', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 147.8076}
# 64: {'_id': ObjectId('66fd0caa72762b446c953d30'), 'Item_Identifier': 'FDY45', 'Item_Weight': nan, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.026015519, 'Item_Type': 'Snack Foods', 'Item_MRP': 255.8356, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 2543.356}
# 65: {'_id': ObjectId('66fd0caa72762b446c953d31'), 'Item_Identifier': 'FDC46', 'Item_Weight': 17.7, 'Item_Fat_Content': 'LF', 'Item_Visibility': 0.195068226, 'Item_Type': 'Snack Foods', 'Item_MRP': 185.4266, 'Outlet_Identifier': 'OUT010', 'Outlet_Establishment_Year': 1998, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 184.4266}
# 66: {'_id': ObjectId('66fd0caa72762b446c953d32'), 'Item_Identifier': 'FDH19', 'Item_Weight': 19.35, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.033082215, 'Item_Type': 'Meat', 'Item_MRP': 172.5738, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 4865.6664}
# 67: {'_id': ObjectId('66fd0caa72762b446c953d33'), 'Item_Identifier': 'FDZ03', 'Item_Weight': 13.65, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.078946455, 'Item_Type': 'Dairy', 'Item_MRP': 186.024, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1118.544}
# 68: {'_id': ObjectId('66fd0caa72762b446c953d34'), 'Item_Identifier': 'DRH37', 'Item_Weight': 17.6, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.041700756, 'Item_Type': 'Soft Drinks', 'Item_MRP': 164.8526, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2302.3364}
# 69: {'_id': ObjectId('66fd0caa72762b446c953d35'), 'Item_Identifier': 'NCI17', 'Item_Weight': 8.645, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.143422643, 'Item_Type': 'Health and Hygiene', 'Item_MRP': 95.841, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2027.361}
# 70: {'_id': ObjectId('66fd0caa72762b446c953d36'), 'Item_Identifier': 'FDJ58', 'Item_Weight': 15.6, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.105296072, 'Item_Type': 'Snack Foods', 'Item_MRP': 170.1764, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 3435.528}
# 71: {'_id': ObjectId('66fd0caa72762b446c953d37'), 'Item_Identifier': 'FDL12', 'Item_Weight': 15.85, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.121531501, 'Item_Type': 'Baking Goods', 'Item_MRP': 59.222, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 599.22}
# 72: {'_id': ObjectId('66fd0caa72762b446c953d38'), 'Item_Identifier': 'FDH35', 'Item_Weight': 18.25, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.0, 'Item_Type': 'Starchy Foods', 'Item_MRP': 164.7526, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 4604.6728}
# 73: {'_id': ObjectId('66fd0caa72762b446c953d39'), 'Item_Identifier': 'FDG02', 'Item_Weight': 7.855, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.011324862, 'Item_Type': 'Canned', 'Item_MRP': 189.6188, 'Outlet_Identifier': 'OUT017', 'Outlet_Establishment_Year': 2007, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2285.0256}
# 74: {'_id': ObjectId('66fd0caa72762b446c953d3a'), 'Item_Identifier': 'NCZ18', 'Item_Weight': 7.825, 'Item_Fat_Content': 'low fat', 'Item_Visibility': 0.186357148, 'Item_Type': 'Household', 'Item_MRP': 254.3698, 'Outlet_Identifier': 'OUT049', 'Outlet_Establishment_Year': 1999, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 5580.7356}
# 75: {'_id': ObjectId('66fd0caa72762b446c953d3b'), 'Item_Identifier': 'FDC29', 'Item_Weight': 8.39, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.024205661, 'Item_Type': 'Frozen Foods', 'Item_MRP': 114.0176, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2290.352}
# 76: {'_id': ObjectId('66fd0caa72762b446c953d3c'), 'Item_Identifier': 'FDQ10', 'Item_Weight': 12.85, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.033230816, 'Item_Type': 'Snack Foods', 'Item_MRP': 172.3422, 'Outlet_Identifier': 'OUT049', 'Outlet_Establishment_Year': 1999, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1207.0954}
# 77: {'_id': ObjectId('66fd0caa72762b446c953d3d'), 'Item_Identifier': 'FDN48', 'Item_Weight': nan, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.113720344, 'Item_Type': 'Baking Goods', 'Item_MRP': 89.9804, 'Outlet_Identifier': 'OUT019', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 643.1628}
# 78: {'_id': ObjectId('66fd0caa72762b446c953d3e'), 'Item_Identifier': 'FDL04', 'Item_Weight': 19.0, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.112556507, 'Item_Type': 'Frozen Foods', 'Item_MRP': 104.9622, 'Outlet_Identifier': 'OUT017', 'Outlet_Establishment_Year': 2007, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1587.933}
# 79: {'_id': ObjectId('66fd0caa72762b446c953d3f'), 'Item_Identifier': 'FDV25', 'Item_Weight': 5.905, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.0, 'Item_Type': 'Canned', 'Item_MRP': 222.5456, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 5305.0944}
# 80: {'_id': ObjectId('66fd0caa72762b446c953d40'), 'Item_Identifier': 'FDD58', 'Item_Weight': 7.76, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.059352241, 'Item_Type': 'Snack Foods', 'Item_MRP': 101.87, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1697.79}
# 81: {'_id': ObjectId('66fd0caa72762b446c953d41'), 'Item_Identifier': 'FDN04', 'Item_Weight': 11.8, 'Item_Fat_Content': 'reg', 'Item_Visibility': 0.014087057, 'Item_Type': 'Frozen Foods', 'Item_MRP': 180.3344, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1427.4752}
# 82: {'_id': ObjectId('66fd0caa72762b446c953d42'), 'Item_Identifier': 'FDV45', 'Item_Weight': 16.75, 'Item_Fat_Content': 'low fat', 'Item_Visibility': 0.045230944, 'Item_Type': 'Snack Foods', 'Item_MRP': 187.9556, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 4693.89}
# 83: {'_id': ObjectId('66fd0caa72762b446c953d43'), 'Item_Identifier': 'NCL18', 'Item_Weight': nan, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.293417759, 'Item_Type': 'Household', 'Item_MRP': 194.6136, 'Outlet_Identifier': 'OUT019', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 583.2408}
# 84: {'_id': ObjectId('66fd0caa72762b446c953d44'), 'Item_Identifier': 'FDR12', 'Item_Weight': nan, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.031382044, 'Item_Type': 'Baking Goods', 'Item_MRP': 171.3764, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 3091.9752}
# 85: {'_id': ObjectId('66fd0caa72762b446c953d45'), 'Item_Identifier': 'FDG20', 'Item_Weight': 15.5, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.12639886, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 177.0028, 'Outlet_Identifier': 'OUT017', 'Outlet_Establishment_Year': 2007, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2479.4392}
# 86: {'_id': ObjectId('66fd0caa72762b446c953d46'), 'Item_Identifier': 'FDZ55', 'Item_Weight': 6.055, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.025403898, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 160.992, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2716.464}
# 87: {'_id': ObjectId('66fd0caa72762b446c953d47'), 'Item_Identifier': 'FDQ49', 'Item_Weight': nan, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.039057677, 'Item_Type': 'Breakfast', 'Item_MRP': 155.963, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 3285.723}
# 88: {'_id': ObjectId('66fd0caa72762b446c953d48'), 'Item_Identifier': 'FDN33', 'Item_Weight': 6.305, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.123115764, 'Item_Type': 'Snack Foods', 'Item_MRP': 95.6436, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 661.8052}
# 89: {'_id': ObjectId('66fd0caa72762b446c953d49'), 'Item_Identifier': 'FDN27', 'Item_Weight': 20.85, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.039624006, 'Item_Type': 'Meat', 'Item_MRP': 117.2808, 'Outlet_Identifier': 'OUT049', 'Outlet_Establishment_Year': 1999, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1523.3504}
# 90: {'_id': ObjectId('66fd0caa72762b446c953d4a'), 'Item_Identifier': 'FDW20', 'Item_Weight': 20.75, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.040421193, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 122.173, 'Outlet_Identifier': 'OUT010', 'Outlet_Establishment_Year': 1998, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 369.519}
# 91: {'_id': ObjectId('66fd0caa72762b446c953d4b'), 'Item_Identifier': 'DRG27', 'Item_Weight': 8.895, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.105274111, 'Item_Type': 'Dairy', 'Item_MRP': 39.9138, 'Outlet_Identifier': 'OUT049', 'Outlet_Establishment_Year': 1999, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 690.4346}
# 92: {'_id': ObjectId('66fd0caa72762b446c953d4c'), 'Item_Identifier': 'DRI25', 'Item_Weight': 19.6, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.033970195, 'Item_Type': 'Soft Drinks', 'Item_MRP': 55.1614, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1381.535}
# 93: {'_id': ObjectId('66fd0caa72762b446c953d4d'), 'Item_Identifier': 'FDA44', 'Item_Weight': 19.7, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.053212652, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 57.893, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 622.523}
# 94: {'_id': ObjectId('66fd0caa72762b446c953d4e'), 'Item_Identifier': 'NCR17', 'Item_Weight': 9.8, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.024378706, 'Item_Type': 'Health and Hygiene', 'Item_MRP': 114.5492, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1274.3412}
# 95: {'_id': ObjectId('66fd0caa72762b446c953d4f'), 'Item_Identifier': 'FDU04', 'Item_Weight': nan, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.009714595, 'Item_Type': 'Frozen Foods', 'Item_MRP': 120.0414, 'Outlet_Identifier': 'OUT019', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 487.3656}
# 96: {'_id': ObjectId('66fd0caa72762b446c953d50'), 'Item_Identifier': 'FDF41', 'Item_Weight': 12.15, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.131383762, 'Item_Type': 'Frozen Foods', 'Item_MRP': 246.046, 'Outlet_Identifier': 'OUT049', 'Outlet_Establishment_Year': 1999, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1231.73}
# 97: {'_id': ObjectId('66fd0caa72762b446c953d51'), 'Item_Identifier': 'FDB56', 'Item_Weight': 8.75, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.07461309, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 187.4556, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 3755.112}
# 98: {'_id': ObjectId('66fd0caa72762b446c953d52'), 'Item_Identifier': 'NCP18', 'Item_Weight': nan, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.028459761, 'Item_Type': 'Household', 'Item_MRP': 149.9708, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 4363.6532}
# 99: {'_id': ObjectId('66fd0caa72762b446c953d53'), 'Item_Identifier': 'FDB56', 'Item_Weight': 8.75, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.074627201, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 187.8556, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1314.2892}
# 100: {'_id': ObjectId('66fd0caa72762b446c953d54'), 'Item_Identifier': 'FDT28', 'Item_Weight': 13.3, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.063695084, 'Item_Type': 'Frozen Foods', 'Item_MRP': 151.0708, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1805.6496}
# 101: {'_id': ObjectId('66fd0caa72762b446c953d55'), 'Item_Identifier': 'FDD10', 'Item_Weight': nan, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.045797829, 'Item_Type': 'Snack Foods', 'Item_MRP': 178.5344, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 2854.9504}
# 102: {'_id': ObjectId('66fd0caa72762b446c953d56'), 'Item_Identifier': 'FDW57', 'Item_Weight': 8.31, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.115857223, 'Item_Type': 'Snack Foods', 'Item_MRP': 179.1028, 'Outlet_Identifier': 'OUT049', 'Outlet_Establishment_Year': 1999, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 3896.2616}
# 103: {'_id': ObjectId('66fd0caa72762b446c953d57'), 'Item_Identifier': 'DRB48', 'Item_Weight': 16.75, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.024832806, 'Item_Type': 'Soft Drinks', 'Item_MRP': 38.7822, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 667.7974}
# 104: {'_id': ObjectId('66fd0caa72762b446c953d58'), 'Item_Identifier': 'FDP09', 'Item_Weight': 19.75, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.034027909, 'Item_Type': 'Snack Foods', 'Item_MRP': 212.0902, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 3185.853}
# 105: {'_id': ObjectId('66fd0caa72762b446c953d59'), 'Item_Identifier': 'FDH14', 'Item_Weight': 17.1, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.0467696, 'Item_Type': 'Canned', 'Item_MRP': 141.1838, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2247.7408}
# 106: {'_id': ObjectId('66fd0caa72762b446c953d5a'), 'Item_Identifier': 'FDA47', 'Item_Weight': 10.5, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.116576702, 'Item_Type': 'Baking Goods', 'Item_MRP': 163.121, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1794.331}
# 107: {'_id': ObjectId('66fd0caa72762b446c953d5b'), 'Item_Identifier': 'FDG12', 'Item_Weight': 6.635, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.0, 'Item_Type': 'Baking Goods', 'Item_MRP': 121.3098, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2530.7058}
# 108: {'_id': ObjectId('66fd0caa72762b446c953d5c'), 'Item_Identifier': 'DRE60', 'Item_Weight': nan, 'Item_Fat_Content': 'low fat', 'Item_Visibility': 0.278974075, 'Item_Type': 'Soft Drinks', 'Item_MRP': 225.372, 'Outlet_Identifier': 'OUT019', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 679.116}
# 109: {'_id': ObjectId('66fd0caa72762b446c953d5d'), 'Item_Identifier': 'DRK49', 'Item_Weight': 14.15, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.035913805, 'Item_Type': 'Soft Drinks', 'Item_MRP': 41.4138, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 812.276}
# 110: {'_id': ObjectId('66fd0caa72762b446c953d5e'), 'Item_Identifier': 'FDD03', 'Item_Weight': 13.3, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.079806266, 'Item_Type': 'Dairy', 'Item_MRP': 232.53, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 699.09}
# 111: {'_id': ObjectId('66fd0caa72762b446c953d5f'), 'Item_Identifier': 'FDS52', 'Item_Weight': 8.89, 'Item_Fat_Content': 'low fat', 'Item_Visibility': 0.005505481, 'Item_Type': 'Frozen Foods', 'Item_MRP': 102.4016, 'Outlet_Identifier': 'OUT017', 'Outlet_Establishment_Year': 2007, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2732.4432}
# 112: {'_id': ObjectId('66fd0caa72762b446c953d60'), 'Item_Identifier': 'FDW39', 'Item_Weight': nan, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.064625342, 'Item_Type': 'Meat', 'Item_MRP': 176.937, 'Outlet_Identifier': 'OUT019', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 176.437}
# 113: {'_id': ObjectId('66fd0caa72762b446c953d61'), 'Item_Identifier': 'FDX34', 'Item_Weight': nan, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.071636937, 'Item_Type': 'Snack Foods', 'Item_MRP': 121.7098, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 4097.3332}
# 114: {'_id': ObjectId('66fd0caa72762b446c953d62'), 'Item_Identifier': 'FDV11', 'Item_Weight': 9.1, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.0, 'Item_Type': 'Breads', 'Item_MRP': 173.2054, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 3151.8972}
# 115: {'_id': ObjectId('66fd0caa72762b446c953d63'), 'Item_Identifier': 'FDD17', 'Item_Weight': 7.5, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.032677678, 'Item_Type': 'Frozen Foods', 'Item_MRP': 239.0906, 'Outlet_Identifier': 'OUT049', 'Outlet_Establishment_Year': 1999, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 5942.265}
# 116: {'_id': ObjectId('66fd0caa72762b446c953d64'), 'Item_Identifier': 'FDZ16', 'Item_Weight': 16.85, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.160760054, 'Item_Type': 'Frozen Foods', 'Item_MRP': 192.4478, 'Outlet_Identifier': 'OUT017', 'Outlet_Establishment_Year': 2007, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 4843.695}
# 117: {'_id': ObjectId('66fd0caa72762b446c953d65'), 'Item_Identifier': 'FDZ46', 'Item_Weight': 7.485, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.06911065, 'Item_Type': 'Snack Foods', 'Item_MRP': 109.0228, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2542.0244}
# 118: {'_id': ObjectId('66fd0caa72762b446c953d66'), 'Item_Identifier': 'DRA12', 'Item_Weight': 11.6, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.041177505, 'Item_Type': 'Soft Drinks', 'Item_MRP': 140.3154, 'Outlet_Identifier': 'OUT017', 'Outlet_Establishment_Year': 2007, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2552.6772}
# ...
# 8484: {'_id': ObjectId('66fd0caa72762b446c955e14'), 'Item_Identifier': 'DRJ49', 'Item_Weight': 6.865, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.0, 'Item_Type': 'Soft Drinks', 'Item_MRP': 129.9652, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2324.9736}
# 8485: {'_id': ObjectId('66fd0caa72762b446c955e15'), 'Item_Identifier': 'DRK37', 'Item_Weight': nan, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.04379158, 'Item_Type': 'Soft Drinks', 'Item_MRP': 189.053, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 6261.849}
# 8486: {'_id': ObjectId('66fd0caa72762b446c955e16'), 'Item_Identifier': 'FDR20', 'Item_Weight': 20.0, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.0, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 46.4744, 'Outlet_Identifier': 'OUT010', 'Outlet_Establishment_Year': 1998, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 45.2744}
# 8487: {'_id': ObjectId('66fd0caa72762b446c955e17'), 'Item_Identifier': 'DRG13', 'Item_Weight': nan, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.037006076, 'Item_Type': 'Soft Drinks', 'Item_MRP': 164.7526, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 4111.315}
# 8488: {'_id': ObjectId('66fd0caa72762b446c955e18'), 'Item_Identifier': 'NCN14', 'Item_Weight': nan, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.09147267, 'Item_Type': 'Others', 'Item_MRP': 184.6608, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 2756.412}
# 8489: {'_id': ObjectId('66fd0caa72762b446c955e19'), 'Item_Identifier': 'FDV13', 'Item_Weight': 17.35, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.027723342, 'Item_Type': 'Canned', 'Item_MRP': 89.6856, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 2109.2544}
# 8490: {'_id': ObjectId('66fd0caa72762b446c955e1a'), 'Item_Identifier': 'FDU44', 'Item_Weight': nan, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.102295904, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 162.3552, 'Outlet_Identifier': 'OUT019', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 487.3656}
# 8491: {'_id': ObjectId('66fd0caa72762b446c955e1b'), 'Item_Identifier': 'FDO03', 'Item_Weight': 10.395, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.037033223, 'Item_Type': 'Meat', 'Item_MRP': 227.9352, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 4809.7392}
# 8492: {'_id': ObjectId('66fd0caa72762b446c955e1c'), 'Item_Identifier': 'FDT34', 'Item_Weight': 9.3, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.174350275, 'Item_Type': 'Snack Foods', 'Item_MRP': 104.4964, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2419.5172}
# 8493: {'_id': ObjectId('66fd0caa72762b446c955e1d'), 'Item_Identifier': 'FDP21', 'Item_Weight': 7.42, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.025886443, 'Item_Type': 'Snack Foods', 'Item_MRP': 189.1872, 'Outlet_Identifier': 'OUT017', 'Outlet_Establishment_Year': 2007, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 4727.18}
# 8494: {'_id': ObjectId('66fd0caa72762b446c955e1e'), 'Item_Identifier': 'NCI54', 'Item_Weight': 15.2, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.0, 'Item_Type': 'Household', 'Item_MRP': 110.4912, 'Outlet_Identifier': 'OUT017', 'Outlet_Establishment_Year': 2007, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1637.868}
# 8495: {'_id': ObjectId('66fd0caa72762b446c955e1f'), 'Item_Identifier': 'FDE22', 'Item_Weight': 9.695, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.029567218, 'Item_Type': 'Snack Foods', 'Item_MRP': 160.492, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 4314.384}
# 8496: {'_id': ObjectId('66fd0caa72762b446c955e20'), 'Item_Identifier': 'FDJ57', 'Item_Weight': 7.42, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.021695674, 'Item_Type': 'Seafood', 'Item_MRP': 185.3582, 'Outlet_Identifier': 'OUT017', 'Outlet_Establishment_Year': 2007, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 3715.164}
# 8497: {'_id': ObjectId('66fd0caa72762b446c955e21'), 'Item_Identifier': 'FDT08', 'Item_Weight': 13.65, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.049209192, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 150.005, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2247.075}
# 8498: {'_id': ObjectId('66fd0caa72762b446c955e22'), 'Item_Identifier': 'NCP54', 'Item_Weight': 15.35, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.035292855, 'Item_Type': 'Household', 'Item_MRP': 124.573, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 1601.249}
# 8499: {'_id': ObjectId('66fd0caa72762b446c955e23'), 'Item_Identifier': 'NCK53', 'Item_Weight': 11.6, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.037574137, 'Item_Type': 'Health and Hygiene', 'Item_MRP': 100.0042, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2976.126}
# 8500: {'_id': ObjectId('66fd0caa72762b446c955e24'), 'Item_Identifier': 'NCQ42', 'Item_Weight': 20.35, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.0, 'Item_Type': 'Household', 'Item_MRP': 125.1678, 'Outlet_Identifier': 'OUT017', 'Outlet_Establishment_Year': 2007, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1907.517}
# 8501: {'_id': ObjectId('66fd0caa72762b446c955e25'), 'Item_Identifier': 'FDW21', 'Item_Weight': 5.34, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.005997615, 'Item_Type': 'Snack Foods', 'Item_MRP': 100.4358, 'Outlet_Identifier': 'OUT017', 'Outlet_Establishment_Year': 2007, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1508.037}
# 8502: {'_id': ObjectId('66fd0caa72762b446c955e26'), 'Item_Identifier': 'NCH43', 'Item_Weight': 8.42, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.070712031, 'Item_Type': 'Household', 'Item_MRP': 216.4192, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 3020.0688}
# 8503: {'_id': ObjectId('66fd0caa72762b446c955e27'), 'Item_Identifier': 'FDQ44', 'Item_Weight': 20.5, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.036133463, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 120.1756, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 3392.9168}
# 8504: {'_id': ObjectId('66fd0caa72762b446c955e28'), 'Item_Identifier': 'NCN18', 'Item_Weight': nan, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.124110734, 'Item_Type': 'Household', 'Item_MRP': 111.7544, 'Outlet_Identifier': 'OUT027', 'Outlet_Establishment_Year': 1985, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type3', 'Item_Outlet_Sales': 4138.6128}
# 8505: {'_id': ObjectId('66fd0caa72762b446c955e29'), 'Item_Identifier': 'FDB46', 'Item_Weight': 10.5, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.094145821, 'Item_Type': 'Snack Foods', 'Item_MRP': 210.8244, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 2117.244}
# 8506: {'_id': ObjectId('66fd0caa72762b446c955e2a'), 'Item_Identifier': 'DRF37', 'Item_Weight': 17.25, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.084676173, 'Item_Type': 'Soft Drinks', 'Item_MRP': 263.191, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 3944.865}
# 8507: {'_id': ObjectId('66fd0caa72762b446c955e2b'), 'Item_Identifier': 'FDN28', 'Item_Weight': 5.88, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.030242184, 'Item_Type': 'Frozen Foods', 'Item_MRP': 101.799, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 515.995}
# 8508: {'_id': ObjectId('66fd0caa72762b446c955e2c'), 'Item_Identifier': 'FDW31', 'Item_Weight': 11.35, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.04324563, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 199.4742, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2587.9646}
# 8509: {'_id': ObjectId('66fd0caa72762b446c955e2d'), 'Item_Identifier': 'FDG45', 'Item_Weight': 8.1, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.214306131, 'Item_Type': 'Fruits and Vegetables', 'Item_MRP': 213.9902, 'Outlet_Identifier': 'OUT010', 'Outlet_Establishment_Year': 1998, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Grocery Store', 'Item_Outlet_Sales': 424.7804}
# 8510: {'_id': ObjectId('66fd0caa72762b446c955e2e'), 'Item_Identifier': 'FDN58', 'Item_Weight': 13.8, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.056861638, 'Item_Type': 'Snack Foods', 'Item_MRP': 231.5984, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 7182.6504}
# 8511: {'_id': ObjectId('66fd0caa72762b446c955e2f'), 'Item_Identifier': 'FDF05', 'Item_Weight': 17.5, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.026980351, 'Item_Type': 'Frozen Foods', 'Item_MRP': 262.591, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 4207.856}
# 8512: {'_id': ObjectId('66fd0caa72762b446c955e30'), 'Item_Identifier': 'FDR26', 'Item_Weight': 20.7, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.04280113, 'Item_Type': 'Dairy', 'Item_MRP': 178.3028, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2479.4392}
# 8513: {'_id': ObjectId('66fd0caa72762b446c955e31'), 'Item_Identifier': 'FDH31', 'Item_Weight': 12.0, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.020407296, 'Item_Type': 'Meat', 'Item_MRP': 99.9042, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 595.2252}
# 8514: {'_id': ObjectId('66fd0caa72762b446c955e32'), 'Item_Identifier': 'FDA01', 'Item_Weight': 15.0, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.054488534, 'Item_Type': 'Canned', 'Item_MRP': 57.5904, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 468.7232}
# 8515: {'_id': ObjectId('66fd0caa72762b446c955e33'), 'Item_Identifier': 'FDH24', 'Item_Weight': 20.7, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.021518435, 'Item_Type': 'Baking Goods', 'Item_MRP': 157.5288, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 1571.288}
# 8516: {'_id': ObjectId('66fd0caa72762b446c955e34'), 'Item_Identifier': 'NCJ19', 'Item_Weight': 18.6, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.118661426, 'Item_Type': 'Others', 'Item_MRP': 58.7588, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 858.882}
# 8517: {'_id': ObjectId('66fd0caa72762b446c955e35'), 'Item_Identifier': 'FDF53', 'Item_Weight': 20.75, 'Item_Fat_Content': 'reg', 'Item_Visibility': 0.083606565, 'Item_Type': 'Frozen Foods', 'Item_MRP': 178.8318, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 3608.636}
# 8518: {'_id': ObjectId('66fd0caa72762b446c955e36'), 'Item_Identifier': 'FDF22', 'Item_Weight': 6.865, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.056783389, 'Item_Type': 'Snack Foods', 'Item_MRP': 214.5218, 'Outlet_Identifier': 'OUT013', 'Outlet_Establishment_Year': 1987, 'Outlet_Size': 'High', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 2778.3834}
# 8519: {'_id': ObjectId('66fd0caa72762b446c955e37'), 'Item_Identifier': 'FDS36', 'Item_Weight': 8.38, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.046982429, 'Item_Type': 'Baking Goods', 'Item_MRP': 108.157, 'Outlet_Identifier': 'OUT045', 'Outlet_Establishment_Year': 2002, 'Outlet_Size': nan, 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 549.285}
# 8520: {'_id': ObjectId('66fd0caa72762b446c955e38'), 'Item_Identifier': 'NCJ29', 'Item_Weight': 10.6, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.035186271, 'Item_Type': 'Health and Hygiene', 'Item_MRP': 85.1224, 'Outlet_Identifier': 'OUT035', 'Outlet_Establishment_Year': 2004, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 2', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 1193.1136}
# 8521: {'_id': ObjectId('66fd0caa72762b446c955e39'), 'Item_Identifier': 'FDN46', 'Item_Weight': 7.21, 'Item_Fat_Content': 'Regular', 'Item_Visibility': 0.145220646, 'Item_Type': 'Snack Foods', 'Item_MRP': 103.1332, 'Outlet_Identifier': 'OUT018', 'Outlet_Establishment_Year': 2009, 'Outlet_Size': 'Medium', 'Outlet_Location_Type': 'Tier 3', 'Outlet_Type': 'Supermarket Type2', 'Item_Outlet_Sales': 1845.5976}
# 8522: {'_id': ObjectId('66fd0caa72762b446c955e3a'), 'Item_Identifier': 'DRG01', 'Item_Weight': 14.8, 'Item_Fat_Content': 'Low Fat', 'Item_Visibility': 0.04487828, 'Item_Type': 'Soft Drinks', 'Item_MRP': 75.467, 'Outlet_Identifier': 'OUT046', 'Outlet_Establishment_Year': 1997, 'Outlet_Size': 'Small', 'Outlet_Location_Type': 'Tier 1', 'Outlet_Type': 'Supermarket Type1', 'Item_Outlet_Sales': 765.67}

# %%
df = pd.DataFrame(list(collection.find()))
df.head()
# Out:
#                         _id Item_Identifier  Item_Weight Item_Fat_Content  \
# 0  66fd0caa72762b446c953cf0           FDA15         9.30          Low Fat
# 1  66fd0caa72762b446c953cf1           DRC01         5.92          Regular
# 2  66fd0caa72762b446c953cf2           FDN15        17.50          Low Fat
# 3  66fd0caa72762b446c953cf3           FDX07        19.20          Regular
# 4  66fd0caa72762b446c953cf4           NCD19         8.93          Low Fat
#
#    Item_Visibility              Item_Type  Item_MRP Outlet_Identifier  \
# 0         0.016047                  Dairy  249.8092            OUT049
# 1         0.019278            Soft Drinks   48.2692            OUT018
# 2         0.016760                   Meat  141.6180            OUT049
# 3         0.000000  Fruits and Vegetables  182.0950            OUT010
# 4         0.000000              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
if "_id" in df.columns.to_list():
    df = df.drop(columns=["_id"], axis=1)

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
